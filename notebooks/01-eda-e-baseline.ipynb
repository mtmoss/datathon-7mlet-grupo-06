# %% [markdown]
# # 01 — EDA e preparação da base (Etapa 1)
#
# Base **Bank Marketing** (`bank-additional-full.csv`). Objetivo: entender os dados,
# checar qualidade, identificar vazamento e gerar a base processada para modelagem.
#
# Rode a partir da raiz do repositório com o ambiente instalado (`pip install -e ".[dev]"`).

# %%
import sys
sys.path.insert(0, "../src")  # permite importar o pacote rodando de notebooks/

import pandas as pd
import matplotlib.pyplot as plt
from datathon_offerexp import data_loader as dl

# paleta do projeto
CINZA, AZUL, ROSA, AMARELO = "#48494D", "#00ACF1", "#EE008B", "#FFF300"
plt.rcParams.update({
    "font.family": "monospace",
    "figure.facecolor": "white", "axes.facecolor": "white",
    "axes.edgecolor": CINZA, "text.color": CINZA, "axes.labelcolor": CINZA,
    "xtick.color": CINZA, "ytick.color": CINZA, "axes.titlecolor": CINZA,
})
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# carrega a base original (caminho relativo a partir de notebooks/)
raw = dl.load_raw(dl.Path("../data/kaggle/bank-additional-full.csv"))
print("shape:", raw.shape)
raw.head()
# Out:
# shape: (41188, 21)
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Qualidade dos dados

# %%
print("Nulos (NaN):", int(raw.isna().sum().sum()))
print("Duplicadas:", int(raw.duplicated().sum()))
print("Conversao y=yes: {:.2f}%".format((raw['y'] == 'yes').mean() * 100))

# ausencias vem como 'unknown', nao como NaN
for c in raw.select_dtypes('object').columns:
    n = (raw[c] == 'unknown').sum()
    if n:
        print(f"  unknown em {c}: {n} ({n/len(raw)*100:.1f}%)")
# Out:
# Nulos (NaN): 0
# Duplicadas: 12
# Conversao y=yes: 11.27%
#   unknown em job: 330 (0.8%)
#   unknown em marital: 80 (0.2%)
#   unknown em education: 1731 (4.2%)
#   unknown em default: 8597 (20.9%)
#   unknown em housing: 990 (2.4%)
#   unknown em loan: 990 (2.4%)

# %% [markdown]
# ## Sinais de conversão

# %%
alvo = (raw['y'] == 'yes').astype(int)
media = alvo.mean() * 100

def conv_por(col):
    g = alvo.groupby(raw[col]).mean().mul(100).sort_values(ascending=False)
    ax = g.plot(kind='bar', color=AZUL, edgecolor=CINZA, figsize=(6, 3.2))
    ax.axhline(media, color=ROSA, ls='--', label=f'media {media:.1f}%')
    ax.set_title(f'Conversao por {col}'); ax.set_ylabel('conversao (%)')
    ax.legend(); plt.tight_layout(); plt.show()

for c in ['job', 'month', 'contact', 'poutcome']:
    conv_por(c)

# %% [markdown]
# ## Base processada
#
# Remove `duration` (vazamento), cria o alvo `subscribed` (0/1) e salva em Parquet.

# %%
df = dl.build_modeling_table(raw)
assert 'duration' not in df.columns, 'duration deveria ter sido removida'
assert 'subscribed' in df.columns
print('processada:', df.shape)
df.head()
# Out:
# processada: (41188, 20)
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  subscribed
# 0          93.994          -36.4      4.857       5191.0           0
# 1          93.994          -36.4      4.857       5191.0           0
# 2          93.994          -36.4      4.857       5191.0           0
# 3          93.994          -36.4      4.857       5191.0           0
# 4          93.994          -36.4      4.857       5191.0           0
